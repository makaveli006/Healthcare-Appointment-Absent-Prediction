# %% [markdown]
# 1) conda create --name medical_app_env python=3.10 -y
# 2) cd src
# 3) pip install -r requirements.txt

# %% [markdown]
# #### NOTE
# * Data downloaded from kaggle had spelling mistakes in some columns
# * Column name 'Hipertension' changed to 'Hypertension'
# * Column name 'Handcap' changed to 'Handicap'
# * Column name 'No-Show' changed to 'No_Show'

# %% [markdown]
# 4) created account in snowflake (company mail must)
# 5) Projects -> Worksheets -> Create Worksheets
# 6) SHOW WAREHOUSES;
# 7) CREATE WAREHOUSE MY_WAREHOUSE;
# 8) Go to settings -> Preferences -> Default warehouse -> MY_WAREHOUSE -> Save

# %% [markdown]
# 9) RUN "./Snowflake_assets/Create APPOINTMENT_DATA table.sql" inside a worksheet in snowflake
# 10) Load "./data/main/full-data/KaggleV2-May-2016.csv" into "MEDICAL_APPOINTMENT_NO_SHOW.APPOINTMENT_SCHEMA.APPOINTMENT_DATA" table through UI
# 11) Perform quick EDA using "Snowflake_assets/Hypothesis based EDA.sql"
