# %% [markdown]
# # CLICK RUN ALL (MUST)
# # SELECT SYSADMIN BEFORE RUN ALL

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Below TIMESTAMP issues are not a issue. The main issue that is blocking us to upload to db is the 'NO-SHOW' column (It should be NO_SHOW)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 👉 TIMESTAMP_NTZ = Timestamp with No Time Zone
# 👉 TIMESTAMP_TZ = Timestamp with Time Zone
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Dataset we download from https://www.kaggle.com/datasets/joniarroba/noshowappointments has column name 'No-show' but it should be 'No_Show' To be uploaded to snowdlake database. (Convention over configuration)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### I have changed the 'Hipertension' to 'Hypertension'
# #### 'Handcap' to 'Handicap'
# #### 'No-Show' to 'No_Show'

# %% [markdown]
# ![image.png](attachment:image.png)
